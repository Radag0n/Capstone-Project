# %%
import pandas as pd
import sqlite3

# %%
df1=pd.read_csv('C:/Users/jdjra/OneDrive/Desktop/Internship/capstone/imdb_data1.csv')

# %%
df1
# Out:
#        Sno                                         Movie_Name  Duration_min  \
# 0        1                                    The Dark Knight           152
# 1        2      The Lord of the Rings: The Return of the King           201
# 2        3                Spider-Man: Across the Spider-Verse           140
# 3        4                                          Inception           148
# 4        5  The Lord of the Rings: The Fellowship of the Ring           178
# ...    ...                                                ...           ...
# 1770  1771                                              Radhe           113
# 1771  1772                                             Race 3           160
# 1772  1773                                  Angels Apocalypse            85
# 1773  1774                              The Cost of Deception           125
# 1774  1775                                            Sadak 2           133
#
# ...

# %%
df2=pd.read_csv('C:/Users/jdjra/OneDrive/Desktop/Internship/capstone/imdb_data2.csv')

# %%
df2
# Out:
#                                              Movie_Name    Votes  \
# 0                                       The Dark Knight  2756999
# 1         The Lord of the Rings: The Return of the King  1905424
# 2                   Spider-Man: Across the Spider-Verse   200317
# 3                                             Inception  2447577
# 4     The Lord of the Rings: The Fellowship of the Ring  1933646
# ...                                                 ...      ...
# 1770                                              Radhe   179099
# 1771                                             Race 3    47867
# 1772                                  Angels Apocalypse    42920
# 1773                              The Cost of Deception    39616
# 1774                                            Sadak 2    96377
#
#       Gross_collection_millions Certification              Star1  \
# 0                        534.86           12A     Christian Bale
# ...

# %%
conn = sqlite3.connect('IMDB_database.db')
cur=conn.cursor()

# %%
df1.to_sql('Table1',conn)
# Out:
# 1775

# %%
df2.to_sql('Table2',conn)
# Out:
# 1775

# %% [markdown]
# # Table 1: Sno, MovieName, Director Name, Duration, genre, ratings
#
#
# # 1)  Display all the details of movies created by directors Christopher and Matt Reeves.

# %%
query = "SELECT * FROM Table1 WHERE Director1 IN ('Christopher Nolan', 'Matt Reeves') OR Director2 IN ('Christopher Nolan', 'Matt Reeves') OR Director3 IN ('Christopher Nolan', 'Matt Reeves') OR Director4 IN ('Christopher Nolan', 'Matt Reeves') OR Director5 IN ('Christopher Nolan', 'Matt Reeves') OR Director6 IN ('Christopher Nolan', 'Matt Reeves')"

cur.execute(query)

movie = cur.fetchall()

for i in movie:
    print(i)
# Out:
# (0, 1, 'The Dark Knight', 152, 2008, 9.0, 84.0, 'Christopher Nolan', None, None, None, None, None)
# (3, 4, 'Inception', 148, 2010, 8.8, 74.0, 'Christopher Nolan', None, None, None, None, None)
# (16, 17, 'The Dark Knight Rises', 164, 2012, 8.4, 78.0, 'Christopher Nolan', None, None, None, None, None)
# (36, 37, 'Batman Begins', 140, 2005, 8.2, 70.0, 'Christopher Nolan', None, None, None, None, None)
# (128, 129, 'Dunkirk', 106, 2017, 7.8, 94.0, 'Christopher Nolan', None, None, None, None, None)
# (130, 131, 'The Batman', 176, 2022, 7.8, 72.0, 'Matt Reeves', None, None, None, None, None)
# (229, 230, 'Dawn of the Planet of the Apes', 130, 2014, 7.6, 79.0, 'Matt Reeves', None, None, None, None, None)
# (313, 314, 'War for the Planet of the Apes', 140, 2017, 7.4, 82.0, 'Matt Reeves', None, None, None, None, None)
# (323, 324, 'Tenet', 150, 2020, 7.3, 69.0, 'Christopher Nolan', None, None, None, None, None)
# ...

# %% [markdown]
# # 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.

# %%
query = "SELECT * FROM Table1 WHERE Duration_min BETWEEN 140 AND 190"

# Execute the query
cur.execute(query)

# Fetch all the movies from the result of the query
movie = cur.fetchall()

# Print the details of the movies
for i in movie:
    print(i)
# Out:
# (0, 1, 'The Dark Knight', 152, 2008, 9.0, 84.0, 'Christopher Nolan', None, None, None, None, None)
# (2, 3, 'Spider-Man: Across the Spider-Verse', 140, 2023, 8.9, 86.0, 'Joaquim Dos Santos', ' Kemp Powers', ' Justin K. Thompson', None, None, None)
# (3, 4, 'Inception', 148, 2010, 8.8, 74.0, 'Christopher Nolan', None, None, None, None, None)
# (4, 5, 'The Lord of the Rings: The Fellowship of the Ring', 178, 2001, 8.8, 92.0, 'Peter Jackson', None, None, None, None, None)
# (5, 6, 'The Lord of the Rings: The Two Towers', 179, 2002, 8.8, 87.0, 'Peter Jackson', None, None, None, None, None)
# (8, 9, 'Soorarai Pottru', 153, 2020, 8.7, None, 'Sudha Kongara', None, None, None, None, None)
# (13, 14, 'Sita Ramam', 163, 2022, 8.6, None, 'Hanu Raghavapudi', None, None, None, None, None)
# (14, 15, 'Gladiator', 155, 2000, 8.5, 67.0, 'Ridley Scott', None, None, None, None, None)
# (16, 17, 'The Dark Knight Rises', 164, 2012, 8.4, 78.0, 'Christopher Nolan', None, None, None, None, None)
# ...

# %% [markdown]
# # 3) Display all details of movies with ratings above 7 in ascending order.

# %%
query = "SELECT * FROM Table1 WHERE Ratings > 7 ORDER BY Ratings ASC"

cur.execute(query)

# Fetch all the movies from the result of the query
movie = cur.fetchall()

# Print the details of the movies
for i in movie:
    print(i)
# Out:
# (434, 435, 'Mission: Impossible', 110, 1996, 7.1, 59.0, 'Brian De Palma', None, None, None, None, None)
# (435, 436, 'Man of Steel', 143, 2013, 7.1, 55.0, 'Zack Snyder', None, None, None, None, None)
# (436, 437, 'Tropic Thunder', 107, 2008, 7.1, 71.0, 'Ben Stiller', None, None, None, None, None)
# (437, 438, 'The Mummy', 124, 1999, 7.1, 48.0, 'Stephen Sommers', None, None, None, None, None)
# (438, 439, 'Free Guy', 115, 2021, 7.1, 62.0, 'Shawn Levy', None, None, None, None, None)
# (439, 440, 'Prey', 100, 2022, 7.1, 71.0, 'Dan Trachtenberg', None, None, None, None, None)
# (440, 441, 'Wrath of Man', 119, 2021, 7.1, 57.0, 'Guy Ritchie', None, None, None, None, None)
# (441, 442, 'American Made', 114, 2017, 7.1, 65.0, 'Doug Liman', None, None, None, None, None)
# (442, 443, 'Iron Man 3', 130, 2013, 7.1, 62.0, 'Shane Black', None, None, None, None, None)
# (443, 444, 'Batman Returns', 126, 1992, 7.1, 68.0, 'Tim Burton', None, None, None, None, None)
# ...

# %% [markdown]
# # 4) Display all movie names in descending order.

# %%
query = "SELECT Movie_Name FROM Table1 ORDER BY Movie_Name DESC"

cur.execute(query)

movie=cur.fetchall()

for i in movie:
    print(i)
# Out:
# ('Æon Flux',)
# ('xXx²: The Next Level',)
# ('xXx: Return of Xander Cage',)
# ('xXx',)
# ('Zoolander 2',)
# ('Zombieland: Double Tap',)
# ('Zombieland',)
# ('Zatoichi: The Blind Swordsman',)
# ('Zathura: A Space Adventure',)
# ("Zack Snyder's Justice League",)
# ('Your Highness',)
# ('Young Guns II: Blaze of Glory',)
# ('Young Guns',)
# ('You Only Live Twice',)
# ("You Don't Mess with the Zohan",)
# ('Yojimbo',)
# ('X-Men: The Last Stand',)
# ('X-Men: First Class',)
# ('X-Men: Days of Future Past',)
# ('X-Men: Dark Phoenix',)
# ('X-Men: Apocalypse',)
# ('X-Men Origins: Wolverine',)
# ('X-Men 2',)
# ('X-Men',)
# ('Wyatt Earp',)
# ('Wrongfully Accused',)
# ('Wrath of the Titans',)
# ('Wrath of Man',)
# ('World War Z',)
# ('Wonder Woman 1984',)
# ('Wonder Woman',)
# ('Wolfwalkers',)
# ('Without Remorse',)
# ('Windtalkers',)
# ("Willy's Wonderland",)
# ('Willow',)
# ('Wild Wild West',)
# ('Wild Target',)
# ('Wild Hogs',)
# ('Wild Card',)
# ('Who Am I?',)
# ('Whiteout',)
# ...

# %% [markdown]
# # 5) Display movie name starts with ‘P’ and their rating is greater than 7.

# %%
query = "SELECT Movie_Name FROM Table1 WHERE Movie_Name LIKE 'P%' AND Ratings > 7"
cur.execute(query)

movie=cur.fetchall()

for i in movie:
    print(i)
# Out:
# ('Princess Mononoke',)
# ('Paan Singh Tomar',)
# ('Pirates of the Caribbean: The Curse of the Black Pearl',)
# ('Predator',)
# ('Ponniyin Selvan',)
# ('Pushpa: The Rise - Part 1',)
# ('Police Story',)
# ("Pirates of the Caribbean: Dead Man's Chest",)
# ('Predestination',)
# ('Patriots Day',)
# ('Point Break',)
# ('Prey',)
# ("Pirates of the Caribbean: At World's End",)
# ('Payback',)

# %% [markdown]
# # Table 2: Movie Name, stars, votes, Genre, Gross collection, popularity, Certification
#
# # 1) Display all movie names with star Arnold Schwarzenegger in ascending order.

# %%
query = """
    SELECT Movie_Name
    FROM Table2
    WHERE Star1 LIKE '%Arnold Schwarzenegger%'
       OR Star2 LIKE '%Arnold Schwarzenegger%'
       OR Star3 LIKE '%Arnold Schwarzenegger%'
       OR Star4 LIKE '%Arnold Schwarzenegger%'
    ORDER BY Movie_Name ASC
"""
cur.execute(query)
movie = cur.fetchall()


for i in movie:
    print(i[0])
# Out:
# Batman & Robin
# Collateral Damage
# Commando
# Conan the Barbarian
# Conan the Destroyer
# End of Days
# Eraser
# Escape Plan
# Kindergarten Cop
# Last Action Hero
# Predator
# Raw Deal
# Red Heat
# Red Sonja
# Sabotage
# Terminator 2: Judgment Day
# Terminator 3: Rise of the Machines
# Terminator Genisys
# Terminator: Dark Fate
# The 6th Day
# The Last Stand
# The Running Man
# The Terminator
# Total Recall
# True Lies

# %% [markdown]
# # 2) Display all details of the movie with the highest number of votes.

# %%
query='SELECT * FROM Table2 WHERE Votes=(SELECT MAX(Votes) FROM Table2)'
cur.execute(query)
movie = cur.fetchall()
column_names = [i[0] for i in cur.description]

for row in movie:
    print(dict(zip(column_names, row)))
# Out:
# {'index': 0, 'Movie_Name': 'The Dark Knight', 'Votes': 2756999, 'Gross_collection_millions': 534.86, 'Certification': '12A', 'Star1': 'Christian Bale', 'Star2': 'Heath Ledger', 'Star3': 'Aaron Eckhart', 'Star4': 'Michael Caine', 'Genre1': 'Action', 'Genre2': 'Crime', 'Genre3': 'Drama'}

# %% [markdown]
# # 3) Display movie names with gross collections in descending order.

# %%
query='SELECT Movie_Name FROM Table2 ORDER BY Gross_collection_millions DESC'
cur.execute(query)
movie = cur.fetchall()
movie
# Out:
# [('Star Wars: Episode VII - The Force Awakens',),
#  ('Avengers: Endgame',),
#  ('Spider-Man: No Way Home',),
#  ('Avatar',),
#  ('Top Gun: Maverick',),
#  ('Black Panther',),
#  ('Avengers: Infinity War',),
#  ('Avatar: The Way of Water',),
#  ('Jurassic World',),
#  ('Avengers Assemble',),
#  ('Star Wars: Episode VIII - The Last Jedi',),
#  ('The Incredibles 2',),
#  ('The Dark Knight',),
#  ('Rogue One',),
#  ('Star Wars: The Rise of Skywalker',),
#  ('Star Wars: Episode I - The Phantom Menace',),
#  ('Avengers: Age of Ultron',),
#  ('Black Panther: Wakanda Forever',),
#  ('The Dark Knight Rises',),
#  ('Captain Marvel',),
#  ('The Hunger Games: Catching Fire',),
#  ("Pirates of the Caribbean: Dead Man's Chest",),
#  ('Jurassic World: Fallen Kingdom',),
#  ('Wonder Woman',),
#  ('Doctor Strange in the Multiverse of Madness',),
#  ('Iron Man 3',),
#  ('Captain America: Civil War',),
#  ('The Hunger Games',),
#  ('Jumanji: Welcome to the Jungle',),
#  ('Spider-Man',),
# ...

# %% [markdown]
# # 4) Display the gross collection of movies with the star Arnold.

# %%
query= """SELECT Movie_Name,Gross_collection_millions FROM Table2 WHERE Star1 LIKE '%Arnold Schwarzenegger%'
       OR Star2 LIKE '%Arnold Schwarzenegger%'
       OR Star3 LIKE '%Arnold Schwarzenegger%'
       OR Star4 LIKE '%Arnold Schwarzenegger%' ORDER BY Gross_collection_millions DESC"""
cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [('Terminator 2: Judgment Day', 204.84),
#  ('Terminator 3: Rise of the Machines', 150.37),
#  ('True Lies', 146.28),
#  ('Total Recall', 119.39),
#  ('Batman & Robin', 107.33),
#  ('Eraser', 101.3),
#  ('Kindergarten Cop', 91.46),
#  ('Terminator Genisys', 89.76),
#  ('End of Days', 66.89),
#  ('Terminator: Dark Fate', 62.25),
#  ('Predator', 59.74),
#  ('Last Action Hero', 50.02),
#  ('Collateral Damage', 40.08),
#  ('Conan the Barbarian', 39.57),
#  ('The Terminator', 38.4),
#  ('The Running Man', 38.12),
#  ('Commando', 35.1),
#  ('Red Heat', 34.99),
#  ('The 6th Day', 34.6),
#  ('Conan the Destroyer', 31.04),
#  ('Escape Plan', 25.13),
#  ('Raw Deal', 16.21),
#  ('The Last Stand', 12.05),
#  ('Sabotage', 10.51),
#  ('Red Sonja', 6.95)]

# %% [markdown]
# # 5) Display all details of movies with comedy and action genres.

# %%
query= """SELECT * FROM Table2 WHERE Genre1 LIKE '%Comedy%' OR Genre1 LIKE '%Action%' 
        OR Genre2 LIKE '%Comedy%' OR Genre2 LIKE '%Action%'
        OR Genre3 LIKE '%Comedy%' OR Genre3 LIKE '%Action%'
        """
cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [(0,
#   'The Dark Knight',
#   2756999,
#   534.86,
#   '12A',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   'Action',
#   'Crime',
#   'Drama'),
#  (1,
#   'The Lord of the Rings: The Return of the King',
#   1905424,
#   377.85,
#   '12A',
#   'Elijah Wood',
#   'Viggo Mortensen',
#   'Ian McKellen',
#   'Orlando Bloom',
#   'Action',
#   'Adventure',
#   'Drama'),
#  (2,
#   'Spider-Man: Across the Spider-Verse',
#   200317,
#   None,
#   'PG',
#   'Shameik Moore',
#   'Hailee Steinfeld',
#   'Brian Tyree Henry',
#   'Luna Lauren Velez',
#   'Animation',
#   'Action',
#   'Adventure'),
#  (3,
#   'Inception',
#   2447577,
#   292.58,
#   '12A',
#   'Leonardo DiCaprio',
#   'Joseph Gordon-Levitt',
#   'Elliot Page',
#   'Ken Watanabe',
#   'Action',
#   'Adventure',
#   'Sci-Fi'),
#  (4,
#   'The Lord of the Rings: The Fellowship of the Ring',
#   1933646,
#   315.54,
#   'PG',
#   'Elijah Wood',
#   'Ian McKellen',
#   'Orlando Bloom',
# ...

# %% [markdown]
# # 1) Display all details from both tables where movie names are the same.

# %%
query= 'SELECT DISTINCT * FROM Table1 INNER JOIN Table2 ON Table1.Movie_Name=Table2.Movie_Name'
cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [(0,
#   1,
#   'The Dark Knight',
#   152,
#   2008,
#   9.0,
#   84.0,
#   'Christopher Nolan',
#   None,
#   None,
#   None,
#   None,
#   None,
#   0,
#   'The Dark Knight',
#   2756999,
#   534.86,
#   '12A',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   'Action',
#   'Crime',
#   'Drama'),
#  (1,
#   2,
#   'The Lord of the Rings: The Return of the King',
#   201,
#   2003,
#   9.0,
#   94.0,
#   'Peter Jackson',
#   None,
#   None,
#   None,
#   None,
#   None,
#   1,
#   'The Lord of the Rings: The Return of the King',
#   1905424,
#   377.85,
#   '12A',
#   'Elijah Wood',
#   'Viggo Mortensen',
#   'Ian McKellen',
#   'Orlando Bloom',
#   'Action',
#   'Adventure',
#   'Drama'),
#  (2,
#   3,
#   'Spider-Man: Across the Spider-Verse',
#   140,
#   2023,
#   8.9,
#   86.0,
#   'Joaquim Dos Santos',
#   ' Kemp Powers',
#   ' Justin K. Thompson',
#   None,
#   None,
#   None,
#   2,
#   'Spider-Man: Across the Spider-Verse',
# ...

# %% [markdown]
# # 2)   Display all movie names, Director, ratings, and gross collection where the genre is action.

# %%
query="""SELECT Table1.Movie_Name,Table1.Director1,Table1.Director2,Table1.Director3,Table1.Director4,Table1.Director5,Table1.Director6,Table1.Ratings,
      Table2.Gross_collection_millions
      FROM Table1
      INNER JOIN Table2 ON Table1.Movie_Name=Table2.Movie_Name
      WHERE Genre1 LIKE '%Action%' 
      OR Genre2 LIKE '%Action%' 
      OR Genre3 LIKE '%Action%'"""
cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [('The Dark Knight',
#   'Christopher Nolan',
#   None,
#   None,
#   None,
#   None,
#   None,
#   9.0,
#   534.86),
#  ('The Lord of the Rings: The Return of the King',
#   'Peter Jackson',
#   None,
#   None,
#   None,
#   None,
#   None,
#   9.0,
#   377.85),
#  ('Spider-Man: Across the Spider-Verse',
#   'Joaquim Dos Santos',
#   ' Kemp Powers',
#   ' Justin K. Thompson',
#   None,
#   None,
#   None,
#   8.9,
#   None),
#  ('Inception', 'Christopher Nolan', None, None, None, None, None, 8.8, 292.58),
#  ('The Lord of the Rings: The Fellowship of the Ring',
#   'Peter Jackson',
#   None,
#   None,
#   None,
#   None,
#   None,
#   8.8,
#   315.54),
#  ('The Lord of the Rings: The Two Towers',
#   'Peter Jackson',
#   None,
#   None,
#   None,
#   None,
#   None,
#   8.8,
#   342.55),
#  ('The Matrix',
#   'Lana Wachowski',
#   ' Lilly Wachowski',
#   None,
#   None,
#   None,
#   None,
#   8.7,
#   171.48),
#  ('Star Wars: Episode V - The Empire Strikes Back',
# ...

# %% [markdown]
# # 3)      Display all details from both tables with the highest gross collection.

# %%
query= 'SELECT DISTINCT * FROM Table1 INNER JOIN Table2 ON Table1.Movie_Name=Table2.Movie_Name ORDER BY Table2.Gross_collection_millions DESC'
cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [(142,
#   143,
#   'Star Wars: Episode VII - The Force Awakens',
#   138,
#   2015,
#   7.8,
#   80.0,
#   'J.J. Abrams',
#   None,
#   None,
#   None,
#   None,
#   None,
#   142,
#   'Star Wars: Episode VII - The Force Awakens',
#   953088,
#   936.66,
#   '12A',
#   'Daisy Ridley',
#   'John Boyega',
#   'Oscar Isaac',
#   'Domhnall Gleeson',
#   'Action',
#   'Adventure',
#   'Sci-Fi'),
#  (19,
#   20,
#   'Avengers: Endgame',
#   181,
#   2019,
#   8.4,
#   78.0,
#   'Anthony Russo',
#   ' Joe Russo',
#   None,
#   None,
#   None,
#   None,
#   19,
#   'Avengers: Endgame',
#   1202299,
#   858.37,
#   '12A',
#   'Robert Downey Jr.',
#   'Chris Evans',
#   'Mark Ruffalo',
#   'Chris Hemsworth',
#   'Action',
#   'Adventure',
#   'Drama'),
#  (37,
#   38,
#   'Spider-Man: No Way Home',
#   148,
#   2021,
#   8.2,
#   71.0,
#   'Jon Watts',
#   None,
#   None,
#   None,
#   None,
#   None,
#   37,
#   'Spider-Man: No Way Home',
#   820220,
#   804.75,
#   '12A',
# ...

# %% [markdown]
# # 4)      Display all details from both tables with the highest ratings

# %%
query= 'SELECT DISTINCT * FROM Table1 INNER JOIN Table2 ON Table1.Movie_Name=Table2.Movie_Name ORDER BY Ratings DESC'
cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [(0,
#   1,
#   'The Dark Knight',
#   152,
#   2008,
#   9.0,
#   84.0,
#   'Christopher Nolan',
#   None,
#   None,
#   None,
#   None,
#   None,
#   0,
#   'The Dark Knight',
#   2756999,
#   534.86,
#   '12A',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   'Action',
#   'Crime',
#   'Drama'),
#  (1,
#   2,
#   'The Lord of the Rings: The Return of the King',
#   201,
#   2003,
#   9.0,
#   94.0,
#   'Peter Jackson',
#   None,
#   None,
#   None,
#   None,
#   None,
#   1,
#   'The Lord of the Rings: The Return of the King',
#   1905424,
#   377.85,
#   '12A',
#   'Elijah Wood',
#   'Viggo Mortensen',
#   'Ian McKellen',
#   'Orlando Bloom',
#   'Action',
#   'Adventure',
#   'Drama'),
#  (2,
#   3,
#   'Spider-Man: Across the Spider-Verse',
#   140,
#   2023,
#   8.9,
#   86.0,
#   'Joaquim Dos Santos',
#   ' Kemp Powers',
#   ' Justin K. Thompson',
#   None,
#   None,
#   None,
#   2,
#   'Spider-Man: Across the Spider-Verse',
# ...

# %% [markdown]
# # 5)      Display all details from both tables with the lowest gross collection and lowest ratings

# %%
query = """
    SELECT *
FROM Table1
INNER JOIN Table2 ON Table1.Movie_Name = Table2.Movie_Name
WHERE Gross_collection_millions = (
    SELECT MIN(Gross_collection_millions)
    FROM Table2
) 
ORDER BY Ratings ASC
LIMIT 11
"""

cur.execute(query)
movie=cur.fetchall()
movie
# Out:
# [(1503,
#   1504,
#   'Wild Card',
#   92,
#   2015,
#   5.6,
#   40.0,
#   'Simon West',
#   None,
#   None,
#   None,
#   None,
#   None,
#   1503,
#   'Wild Card',
#   58229,
#   0.0,
#   '15',
#   'Jason Statham',
#   'Michael Angarano',
#   'Dominik Garcia',
#   'Milo Ventimiglia',
#   'Action',
#   'Crime',
#   'Drama'),
#  (1304,
#   1305,
#   'The Condemned',
#   114,
#   2007,
#   6.0,
#   23.0,
#   'Scott Wiper',
#   None,
#   None,
#   None,
#   None,
#   None,
#   1304,
#   'The Condemned',
#   53644,
#   0.0,
#   '18',
#   'Steve Austin',
#   'Vinnie Jones',
#   'Nathan Jones',
#   'Robert Mammone',
#   'Action',
#   'Crime',
#   'Thriller'),
#  (997,
#   998,
#   'Son of a Gun',
#   108,
#   2014,
#   6.4,
#   49.0,
#   'Julius Avery',
#   None,
#   None,
#   None,
#   None,
#   None,
#   997,
#   'Son of a Gun',
#   28984,
#   0.0,
#   '15',
#   'Ewan McGregor',
#   'Brenton Thwaites',
#   'Alicia Vikander',
#   'Brendan Kerkvliet',
#   'Action',
#   'Crime',
# ...

# %% [markdown]
# # USING PANDAS

# %% [markdown]
# # 1)  Display all the details of movies created by directors Christopher and Matt Reeves.

# %%
directors = ["Christopher Nolan", "Matt Reeves"]
result1 = df1[df1["Director1"].isin(directors)]
result1
# Out:
#      Sno                      Movie_Name  Duration_min  Year  Ratings  \
# 0      1                 The Dark Knight           152  2008      9.0
# 3      4                       Inception           148  2010      8.8
# 16    17           The Dark Knight Rises           164  2012      8.4
# 36    37                   Batman Begins           140  2005      8.2
# 128  129                         Dunkirk           106  2017      7.8
# 130  131                      The Batman           176  2022      7.8
# 229  230  Dawn of the Planet of the Apes           130  2014      7.6
# 313  314  War for the Planet of the Apes           140  2017      7.4
# 323  324                           Tenet           150  2020      7.3
# 523  524                     Cloverfield            85  2008      7.0
#
#      Metascore          Director1 Director2 Director3 Director4 Director5  \
# 0         84.0  Christopher Nolan       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# # 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.

# %%
result2 = df1[(df1['Duration_min'] >= 140) & (df1['Duration_min'] <= 190)]
result2
# Out:
#        Sno                                         Movie_Name  Duration_min  \
# 0        1                                    The Dark Knight           152
# 2        3                Spider-Man: Across the Spider-Verse           140
# 3        4                                          Inception           148
# 4        5  The Lord of the Rings: The Fellowship of the Ring           178
# 5        6              The Lord of the Rings: The Two Towers           179
# ...    ...                                                ...           ...
# 1761  1762                                              Liger           140
# 1762  1763                                             Gunday           152
# 1765  1766                                             Laxmii           141
# 1766  1767                                        Heropanti 2           145
# 1771  1772                                             Race 3           160
#
# ...

# %% [markdown]
# # 3) Display all details of movies with ratings above 7 in ascending order.

# %%
result3 = df1[df1["Ratings"] > 7].sort_values(by="Ratings")
result3
# Out:
#      Sno                                         Movie_Name  Duration_min  \
# 492  493                                     Gabbar Is Back           128
# 459  460                                       Rocky Balboa           102
# 458  459                                         Real Steel           127
# 457  458                                            Everest           121
# 456  457                               Escape from New York            99
# ..   ...                                                ...           ...
# 4      5  The Lord of the Rings: The Fellowship of the Ring           178
# 3      4                                          Inception           148
# 2      3                Spider-Man: Across the Spider-Verse           140
# 1      2      The Lord of the Rings: The Return of the King           201
# 0      1                                    The Dark Knight           152
#
#      Year  Ratings  Metascore                  Director1     Director2  \
# ...

# %% [markdown]
# # 4) Display all movie names in descending order.

# %%
result4 = df1["Movie_Name"].sort_values(ascending=False)
result4
# Out:
# 1585                      Æon Flux
# 1722          xXx²: The Next Level
# 1636    xXx: Return of Xander Cage
# 1391                           xXx
# 1699                   Zoolander 2
#                    ...
# 868                      12 Strong
# 1528                     12 Rounds
# 1658                     10,000 BC
# 426                            '71
# 1051                        #Alive
# Name: Movie_Name, Length: 1775, dtype: object

# %% [markdown]
# # 5) Display movie name starts with ‘P’ and their rating is greater than 7.

# %%
result5 = df1[(df1["Movie_Name"].str.startswith("P")) & (df1["Ratings"] > 7)]
result5
# Out:
#      Sno                                         Movie_Name  Duration_min  \
# 28    29                                  Princess Mononoke           134
# 55    56                                   Paan Singh Tomar           135
# 57    58  Pirates of the Caribbean: The Curse of the Bla...           143
# 140  141                                           Predator           107
# 239  240                                    Ponniyin Selvan           167
# 240  241                          Pushpa: The Rise - Part 1           179
# 274  275                                       Police Story            99
# 304  305         Pirates of the Caribbean: Dead Man's Chest           151
# 305  306                                     Predestination            97
# 360  361                                       Patriots Day           133
# 385  386                                        Point Break           122
# 439  440                                               Prey           100
# ...

# %% [markdown]
# # 1) Display all movie names with star Arnold Schwarzenegger in ascending order.

# %%
stars_columns = ['Star1', 'Star2', 'Star3', 'Star4']
result1 = df2[df2[stars_columns].astype(str).apply(lambda row: any('Arnold Schwarzenegger' in star for star in row), axis=1)].sort_values(by='Movie_Name')
result1
# Out:
#                               Movie_Name    Votes  Gross_collection_millions  \
# 1745                      Batman & Robin   261944                     107.33
# 1560                   Collateral Damage    76866                      40.08
# 704                             Commando   169315                      35.10
# 574                  Conan the Barbarian   157271                      39.57
# 1336                 Conan the Destroyer    83439                      31.04
# 1405                         End of Days   114552                      66.89
# 1136                              Eraser   115892                     101.30
# 689                          Escape Plan   251704                      25.13
# 1101                    Kindergarten Cop   157541                      91.46
# 875                     Last Action Hero   159055                      50.02
# 140                             Predator   438603                      59.74
# ...

# %% [markdown]
# # 2) Display all details of the movie with the highest number of votes.

# %%
max_votes_index = df2['Votes'].idxmax()
result2 = df2.loc[max_votes_index]
result2
# Out:
# Movie_Name                   The Dark Knight
# Votes                                2756999
# Gross_collection_millions             534.86
# Certification                            12A
# Star1                         Christian Bale
# Star2                           Heath Ledger
# Star3                          Aaron Eckhart
# Star4                          Michael Caine
# Genre1                                Action
# Genre2                                 Crime
# Genre3                                 Drama
# Name: 0, dtype: object

# %% [markdown]
# # 3) Display movie names with gross collections in descending order.

# %%
result3 = df2.sort_values(by='Gross_collection_millions', ascending=False)['Movie_Name']
result3
# Out:
# 142     Star Wars: Episode VII - The Force Awakens
# 19                               Avengers: Endgame
# 37                         Spider-Man: No Way Home
# 107                                         Avatar
# 25                               Top Gun: Maverick
#                            ...
# 1768                                 The Prototype
# 1770                                         Radhe
# 1772                             Angels Apocalypse
# 1773                         The Cost of Deception
# 1774                                       Sadak 2
# Name: Movie_Name, Length: 1775, dtype: object

# %% [markdown]
# # 4) Display the gross collection of movies with the star Arnold.

# %%
result4 = df2[df2[stars_columns].astype(str).apply(lambda row: any('Arnold' in star for star in row),axis=1)].sort_values(by='Gross_collection_millions')
result4
# Out:
#                               Movie_Name    Votes  Gross_collection_millions  \
# 1657                           Red Sonja    43714                       6.95
# 1468                            Sabotage    65161                      10.51
# 1037                      The Last Stand   143257                      12.05
# 1502                            Raw Deal    36385                      16.21
# 689                          Escape Plan   251704                      25.13
# 1336                 Conan the Destroyer    83439                      31.04
# 1343                         The 6th Day   125791                      34.60
# 1222                            Red Heat    73967                      34.99
# 704                             Commando   169315                      35.10
# 703                      The Running Man   160308                      38.12
# 59                        The Terminator   894786                      38.40
# ...

# %% [markdown]
# # 5) Display all details of movies with comedy and action genres.

# %%
genre_columns = ['Genre1', 'Genre2', 'Genre3']
result5 = df2[df2[genre_columns].astype(str).apply(lambda row: any("Comedy" in genre for genre in row) and any("Action" in genre for genre in row), axis=1)]
result5
# Out:
#                                        Movie_Name   Votes  \
# 46                             Gangs of Wasseypur  100114
# 51                                   Sherlock Jr.   53449
# 64            Lock, Stock and Two Smoking Barrels  599556
# 69                                    The General   94920
# 71                              Bajrangi Bhaijaan   92985
# ...                                           ...     ...
# 1744                                   Pluto Nash   26565
# 1749  The Adventures of Sharkboy and Lavagirl 3-D   40451
# 1754        Spy Kids 4: All the Time in the World   27277
# 1765                                       Laxmii   58171
# 1766                                  Heropanti 2   27082
#
#       Gross_collection_millions Certification           Star1  \
# 46                          NaN            18  Manoj Bajpayee
# 51                         0.98             U   Buster Keaton
# 64                         3.90            18   Jason Flemyng
# ...

# %% [markdown]
# # 1) Display all details from both tables where movie names are the same.

# %%
result1 = pd.merge(df1, df2, left_on='Movie_Name', right_on='Movie_Name', how='inner')
result1
# Out:
#        Sno                                         Movie_Name  Duration_min  \
# 0        1                                    The Dark Knight           152
# 1        2      The Lord of the Rings: The Return of the King           201
# 2        3                Spider-Man: Across the Spider-Verse           140
# 3        4                                          Inception           148
# 4        5  The Lord of the Rings: The Fellowship of the Ring           178
# ...    ...                                                ...           ...
# 1850  1771                                              Radhe           113
# 1851  1772                                             Race 3           160
# 1852  1773                                  Angels Apocalypse            85
# 1853  1774                              The Cost of Deception           125
# 1854  1775                                            Sadak 2           133
#
# ...

# %% [markdown]
# # 2)   Display all movie names, Director, ratings, and gross collection where the genre is action.

# %%
genre_columns = ['Genre1', 'Genre2', 'Genre3']
result2 = result1[result1[genre_columns].apply(lambda row: any("Action" in genre for genre in row), axis=1)][['Movie_Name', 'Director1', 'Director2', 'Ratings', 'Gross_collection_millions']]
result2
# Out:
#                                              Movie_Name           Director1  \
# 0                                       The Dark Knight   Christopher Nolan
# 1         The Lord of the Rings: The Return of the King       Peter Jackson
# 2                   Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3                                             Inception   Christopher Nolan
# 4     The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
# ...                                                 ...                 ...
# 1850                                              Radhe         Prabhu Deva
# 1851                                             Race 3        Remo D'Souza
# 1852                                  Angels Apocalypse           Sean Cain
# 1853                              The Cost of Deception       Keith English
# 1854                                            Sadak 2        Mahesh Bhatt
#
#            Director2  Ratings  Gross_collection_millions
# ...

# %% [markdown]
# # 3)      Display all details from both tables with the highest gross collection.

# %%
result3=result1[result1['Gross_collection_millions'] == result1['Gross_collection_millions'].max()]
result3
# Out:
#      Sno                                  Movie_Name  Duration_min  Year  \
# 156  143  Star Wars: Episode VII - The Force Awakens           138  2015
#
#      Ratings  Metascore    Director1 Director2 Director3 Director4  ...  \
# 156      7.8       80.0  J.J. Abrams       NaN       NaN       NaN  ...
#
#       Votes Gross_collection_millions  Certification         Star1  \
# 156  953088                    936.66            12A  Daisy Ridley
#
#            Star2        Star3             Star4  Genre1     Genre2  Genre3
# 156  John Boyega  Oscar Isaac  Domhnall Gleeson  Action  Adventure  Sci-Fi
#
# [1 rows x 22 columns]

# %% [markdown]
# # 4)      Display all details from both tables with the highest ratings

# %%
result4 = result1[result1['Ratings'] == result1['Ratings'].max()]
result4
# Out:
#    Sno                                     Movie_Name  Duration_min  Year  \
# 0    1                                The Dark Knight           152  2008
# 1    2  The Lord of the Rings: The Return of the King           201  2003
#
#    Ratings  Metascore          Director1 Director2 Director3 Director4  ...  \
# 0      9.0       84.0  Christopher Nolan       NaN       NaN       NaN  ...
# 1      9.0       94.0      Peter Jackson       NaN       NaN       NaN  ...
#
#      Votes Gross_collection_millions  Certification           Star1  \
# 0  2756999                    534.86            12A  Christian Bale
# 1  1905424                    377.85            12A     Elijah Wood
#
#              Star2          Star3          Star4  Genre1     Genre2 Genre3
# 0     Heath Ledger  Aaron Eckhart  Michael Caine  Action      Crime  Drama
# 1  Viggo Mortensen   Ian McKellen  Orlando Bloom  Action  Adventure  Drama
#
# [2 rows x 22 columns]

# %% [markdown]
# # 5)      Display all details from both tables with the lowest gross collection and lowest ratings

# %%
result5 = result1[(result1['Ratings'] == result1['Ratings'].min()) | (result1['Gross_collection_millions'] == result1['Gross_collection_millions'].min())]
result5
# Out:
#        Sno                 Movie_Name  Duration_min  Year  Ratings  Metascore  \
# 178    165  Knockin' on Heaven's Door            87  1997      7.8        NaN
# 1086   998               Son of a Gun           108  2014      6.4       49.0
# 1395  1305              The Condemned           114  2007      6.0       23.0
# 1597  1504                  Wild Card            92  2015      5.6       40.0
# 1854  1775                    Sadak 2           133  2020      1.2        NaN
#
#          Director1 Director2 Director3 Director4  ...  Votes  \
# 178    Thomas Jahn       NaN       NaN       NaN  ...  32422
# 1086  Julius Avery       NaN       NaN       NaN  ...  28984
# 1395   Scott Wiper       NaN       NaN       NaN  ...  53644
# 1597    Simon West       NaN       NaN       NaN  ...  58229
# 1854  Mahesh Bhatt       NaN       NaN       NaN  ...  96377
#
#      Gross_collection_millions  Certification          Star1  \
# 178                        0.0            NaN  Til Schweiger
# ...
